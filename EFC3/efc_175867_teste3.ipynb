# %% [markdown]
# # EFC 3 - Redes Neurais - IA048
#
# ## Aluno: Jitesh Ashok Manilal Vassaram, RA:175867

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
tf.config.threading.set_intra_op_parallelism_threads(10)
# tf.config.threading.set_inter_op_parallelism_threads(10)

# %%
data = np.load('../EFC3/bloodmnist.npz')

# %%
TrainX = data["train_images"]
TrainY = data["train_labels"]
ValX = data["val_images"]
ValY = data["val_labels"]
TestX = data["test_images"]
TestY = data["test_labels"]

# %%
print(f'dados de treinamento: \n {len(TrainX[0])}')

print('--'*20)
print(f'\n {TrainX/255}')
# Out:
# dados de treinamento:
#  28
# ----------------------------------------
#
#  [[[[0.98039216 0.8745098  0.80784314]
#    [1.         0.89803922 0.83137255]
#    [0.98431373 0.87058824 0.80784314]
#    ...
#    [1.         0.93333333 0.76470588]
#    [0.98431373 0.90196078 0.7254902 ]
#    [1.         0.91764706 0.74901961]]
#
#   [[1.         0.89803922 0.82352941]
#    [1.         0.89803922 0.82352941]
#    [0.95686275 0.84313725 0.78039216]
#    ...
#    [0.99607843 0.90980392 0.75686275]
#    [0.99607843 0.91372549 0.74509804]
#    [1.         0.94901961 0.78823529]]
#
#   [[1.         0.90588235 0.81568627]
#    [1.         0.89019608 0.80392157]
#    [0.93333333 0.82352941 0.74117647]
#    ...
#    [1.         0.91372549 0.79215686]
#    [0.98431373 0.89803922 0.75294118]
#    [1.         0.94901961 0.79607843]]
#
#   ...
#
#   [[0.91372549 0.8        0.6745098 ]
#    [0.9372549  0.82352941 0.70588235]
#    [0.96078431 0.85490196 0.7372549 ]
#    ...
#    [1.         0.88235294 0.78039216]
#    [1.         0.88627451 0.78431373]
#    [1.         0.89411765 0.78039216]]
#
#   [[0.84313725 0.72156863 0.61176471]
#    [0.85490196 0.7372549  0.62745098]
#    [0.89411765 0.77647059 0.66666667]
#    ...
#    [1.         0.88235294 0.78823529]
#    [0.99607843 0.89019608 0.78431373]
#    [1.         0.89411765 0.78823529]]
#
#   [[0.85098039 0.71372549 0.63529412]
#    [0.83137255 0.70588235 0.62352941]
#    [0.83529412 0.70980392 0.61960784]
#    ...
#    [0.99607843 0.88627451 0.8       ]
#    [1.         0.89019608 0.79607843]
#    [1.         0.89411765 0.78823529]]]
#
#
#  [[[1.         0.90980392 0.83529412]
#    [0.99607843 0.89019608 0.80784314]
#    [0.98431373 0.88235294 0.78431373]
#    ...
#    [0.68627451 0.5254902  0.55686275]
#    [0.63137255 0.46666667 0.51372549]
#    [0.61176471 0.45098039 0.51372549]]
#
#   [[0.99215686 0.89019608 0.79215686]
#    [1.         0.90196078 0.80392157]
#    [1.         0.90980392 0.80392157]
#    ...
#    [0.64705882 0.48627451 0.51764706]
#    [0.61960784 0.45490196 0.50980392]
#    [0.61960784 0.45882353 0.52156863]]
#
#   [[0.97647059 0.87843137 0.75686275]
#    [1.         0.90980392 0.78823529]
#    [1.         0.91764706 0.79607843]
#    ...
#    [0.6627451  0.49803922 0.54509804]
#    [0.65490196 0.49411765 0.55686275]
#    [0.68235294 0.52156863 0.59215686]]
#
#   ...
#
#   [[0.99607843 0.91372549 0.7372549 ]
#    [0.99607843 0.91372549 0.74509804]
#    [0.99607843 0.90980392 0.75686275]
#    ...
#    [0.75294118 0.60784314 0.57647059]
#    ...
#    [0.82745098 0.69019608 0.66666667]
#    [0.83921569 0.70196078 0.69411765]
#    [0.84705882 0.70588235 0.70588235]]
#
#   ...
#
#   [[1.         0.89019608 0.82745098]
#    [1.         0.89019608 0.81960784]
#    [1.         0.88627451 0.81568627]
#    ...
#    [0.79215686 0.63921569 0.61176471]
#    [0.81568627 0.65882353 0.65098039]
#    [0.86666667 0.70980392 0.70980392]]
#
#   [[1.         0.89019608 0.82745098]
#    [1.         0.88627451 0.82352941]
#    [1.         0.88627451 0.82352941]
#    ...
#    [0.76470588 0.61960784 0.58823529]
#    [0.81176471 0.65490196 0.64705882]
#    [0.88627451 0.72941176 0.72941176]]
#
#   [[1.         0.88627451 0.82352941]
#    [1.         0.88627451 0.82352941]
#    [1.         0.88627451 0.82352941]
#    ...
#    [0.76470588 0.61960784 0.59607843]
#    [0.80784314 0.65882353 0.65490196]
#    [0.87843137 0.72941176 0.7254902 ]]]]

# %%
plt.imshow(TestX[0])
plt.colorbar()
plt.show()

# %%
TrainX_n = TrainX/255
TestX_n = TestX/255
ValX_n = ValX/255

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(TrainX_n[i], cmap=plt.cm.binary)
    # plt.xlabel(class_names[TrainY[i]])
plt.show()

# %% [markdown]
# # Criação do modelo CNN profunda
#
# Será implementado uma CNN profunda. Será tomada como base a DenseNet para a construção da CNN.

# %% [markdown]
# Para a construção, utilizou-se o seguinte exemplo que aplica uma DenseNet:
# [Classificação_KERAS_DenseNet](https://towardsdatascience.com/exploring-densenets-from-paper-to-keras-dcc01725488b)

# %%
def H(input, num_filters, dropout_rate):
    
    x = tf.keras.layers.BatchNormalization()(input)
    x = tf.keras.layers.Activation('relu')(x)
    x = tf.keras.layers.Conv2D(num_filters,kernel_size=(1,1),use_bias=False)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    x = tf.keras.layers.ZeroPadding2D((1,1))(x)
    x = tf.keras.layers.Conv2D(num_filters, kernel_size=(3,3),use_bias=False)(x)
    x = tf.keras.layers.Dropout(rate=dropout_rate)(x)

    return x

# %%
def transition(inputs, num_filters, compression_factor, dropout_rate,eps):
    
    x = tf.keras.layers.BatchNormalization()(inputs)
    x = tf.keras.layers.Activation('relu')(x)
    num_feature_maps = inputs.shape[1]

    x = tf.keras.layers.Conv2D(np.floor(compression_factor * num_feature_maps).astype(np.int64), kernel_size=(1,1), use_bias=False, padding='same', kernel_regularizer=tf.keras.regularizers.l2( eps ) )(x)
    x = tf.keras.layers.Dropout(rate=dropout_rate)(x)
    x = tf.keras.layers.AveragePooling2D(pool_size=(2,2))(x)
    return x

# %%
def dense_blk(inputs, num_layers, num_filters, growth_rate, dropout_rate,eps):
    
    for i in range(num_layers):
        conv_out = H(inputs, num_filters, dropout_rate)
        inputs = tf.keras.layers.Concatenate()([conv_out,inputs])
        num_filters += growth_rate


    return inputs, num_filters

# %%
# Programa Final para construir o modelo.

input_shape = (28,28,3)
eps = 1.1e-4
num_block = 2
num_layer_pblock = 2
growth_rate = 4
dropout_rate = 0.4
compression_factor = 0.5

num_filters = 8

inputs = tf.keras.layers.Input(shape=input_shape)
x = tf.keras.layers.Conv2D(num_filters, kernel_size=(3,3), use_bias=False, kernel_regularizer=tf.keras.regularizers.l2(eps))(inputs)

for i in range(num_block):
    x,num_filters = dense_blk(x, num_layer_pblock, num_filters, growth_rate, dropout_rate,eps)
    x = transition(x, num_filters, compression_factor, dropout_rate,eps)

x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dense(8)(x)

output = tf.keras.layers.Activation('softmax')(x)

# %%
model = tf.keras.models.Model(inputs, output)

model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(), optimizer=tf.keras.optimizers.Adam(learning_rate=0.005), metrics=['acc'])
model.summary()
# Out:
# Model: "functional_19"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_9       │ (None, 28, 28, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_107 (Conv2D) │ (None, 26, 26, 8) │        216 │ input_layer_9[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 26, 26, 8) │         32 │ conv2d_107[0][0]  │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_107      │ (None, 26, 26, 8) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_108 (Conv2D) │ (None, 26, 26, 8) │         64 │ activation_107[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 26, 26, 8) │         32 │ conv2d_108[0][0]  │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_108      │ (None, 26, 26, 8) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_40   │ (None, 28, 28, 8) │          0 │ activation_108[0… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_109 (Conv2D) │ (None, 26, 26, 8) │        576 │ zero_padding2d_4… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_58          │ (None, 26, 26, 8) │          0 │ conv2d_109[0][0]  │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_40      │ (None, 26, 26,    │          0 │ dropout_58[0][0], │
# │ (Concatenate)       │ 16)               │            │ conv2d_107[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 26, 26,    │         64 │ concatenate_40[0… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_109      │ (None, 26, 26,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_110 (Conv2D) │ (None, 26, 26,    │        192 │ activation_109[0… │
# │                     │ 12)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 26, 26,    │         48 │ conv2d_110[0][0]  │
# │ (BatchNormalizatio… │ 12)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_110      │ (None, 26, 26,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 12)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_41   │ (None, 28, 28,    │          0 │ activation_110[0… │
# │ (ZeroPadding2D)     │ 12)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_111 (Conv2D) │ (None, 26, 26,    │      1,296 │ zero_padding2d_4… │
# │                     │ 12)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_59          │ (None, 26, 26,    │          0 │ conv2d_111[0][0]  │
# │ (Dropout)           │ 12)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_41      │ (None, 26, 26,    │          0 │ dropout_59[0][0], │
# │ (Concatenate)       │ 28)               │            │ concatenate_40[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 26, 26,    │        112 │ concatenate_41[0… │
# │ (BatchNormalizatio… │ 28)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_111      │ (None, 26, 26,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 28)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_112 (Conv2D) │ (None, 26, 26,    │        364 │ activation_111[0… │
# │                     │ 13)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_60          │ (None, 26, 26,    │          0 │ conv2d_112[0][0]  │
# │ (Dropout)           │ 13)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_… │ (None, 13, 13,    │          0 │ dropout_60[0][0]  │
# │ (AveragePooling2D)  │ 13)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 13, 13,    │         52 │ average_pooling2… │
# │ (BatchNormalizatio… │ 13)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_112      │ (None, 13, 13,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 13)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_113 (Conv2D) │ (None, 13, 13,    │        208 │ activation_112[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 13, 13,    │         64 │ conv2d_113[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_113      │ (None, 13, 13,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_42   │ (None, 15, 15,    │          0 │ activation_113[0… │
# │ (ZeroPadding2D)     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_114 (Conv2D) │ (None, 13, 13,    │      2,304 │ zero_padding2d_4… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_61          │ (None, 13, 13,    │          0 │ conv2d_114[0][0]  │
# │ (Dropout)           │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_42      │ (None, 13, 13,    │          0 │ dropout_61[0][0], │
# │ (Concatenate)       │ 29)               │            │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 13, 13,    │        116 │ concatenate_42[0… │
# │ (BatchNormalizatio… │ 29)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_114      │ (None, 13, 13,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 29)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_115 (Conv2D) │ (None, 13, 13,    │        580 │ activation_114[0… │
# │                     │ 20)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 13, 13,    │         80 │ conv2d_115[0][0]  │
# │ (BatchNormalizatio… │ 20)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_115      │ (None, 13, 13,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 20)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ zero_padding2d_43   │ (None, 15, 15,    │          0 │ activation_115[0… │
# │ (ZeroPadding2D)     │ 20)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_116 (Conv2D) │ (None, 13, 13,    │      3,600 │ zero_padding2d_4… │
# │                     │ 20)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_62          │ (None, 13, 13,    │          0 │ conv2d_116[0][0]  │
# │ (Dropout)           │ 20)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_43      │ (None, 13, 13,    │          0 │ dropout_62[0][0], │
# │ (Concatenate)       │ 49)               │            │ concatenate_42[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 13, 13,    │        196 │ concatenate_43[0… │
# │ (BatchNormalizatio… │ 49)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_116      │ (None, 13, 13,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 49)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_117 (Conv2D) │ (None, 13, 13, 6) │        294 │ activation_116[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_63          │ (None, 13, 13, 6) │          0 │ conv2d_117[0][0]  │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_… │ (None, 6, 6, 6)   │          0 │ dropout_63[0][0]  │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 6)         │          0 │ average_pooling2… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 8)         │         56 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_117      │ (None, 8)         │          0 │ dense_9[0][0]     │
# │ (Activation)        │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 10,546 (41.20 KB)
#  Trainable params: 10,148 (39.64 KB)
#  Non-trainable params: 398 (1.55 KB)

# %%
batch_size = 64
epochs = 100

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=25, restore_best_weights=True)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)
# hist = model.fit(datagen.flow(TrainX_n, TrainY, batch_size=batch_size, seed=seed),epochs=epochs, batch_size=batch_size, validation_data=(ValX_n,ValY))
hist = model.fit(TrainX_n,TrainY,epochs=epochs, batch_size=batch_size, validation_data=(ValX_n,ValY),callbacks=[early_stopping, reduce_lr])
# Out:
# Epoch 1/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - acc: 0.5627 - loss: 1.1974 - val_acc: 0.0905 - val_loss: 10.4349 - learning_rate: 0.0050
# Epoch 2/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - acc: 0.8115 - loss: 0.5212 - val_acc: 0.3738 - val_loss: 7.3382 - learning_rate: 0.0050
# Epoch 3/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - acc: 0.8387 - loss: 0.4391 - val_acc: 0.4147 - val_loss: 2.1431 - learning_rate: 0.0050
# Epoch 4/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - acc: 0.8486 - loss: 0.4204 - val_acc: 0.4895 - val_loss: 4.3444 - learning_rate: 0.0050
# Epoch 5/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - acc: 0.8612 - loss: 0.3891 - val_acc: 0.4539 - val_loss: 2.2887 - learning_rate: 0.0050
# Epoch 6/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - acc: 0.8542 - loss: 0.3951 - val_acc: 0.4422 - val_loss: 4.9081 - learning_rate: 0.0050
# Epoch 7/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - acc: 0.8753 - loss: 0.3476 - val_acc: 0.6682 - val_loss: 0.9136 - learning_rate: 0.0025
# Epoch 8/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - acc: 0.8744 - loss: 0.3468 - val_acc: 0.4422 - val_loss: 6.5785 - learning_rate: 0.0025
# Epoch 9/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - acc: 0.8757 - loss: 0.3341 - val_acc: 0.7967 - val_loss: 0.6839 - learning_rate: 0.0025
# Epoch 10/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - acc: 0.8841 - loss: 0.3297 - val_acc: 0.5888 - val_loss: 1.5108 - learning_rate: 0.0025
# Epoch 11/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - acc: 0.8879 - loss: 0.3186 - val_acc: 0.6133 - val_loss: 1.1636 - learning_rate: 0.0025
# Epoch 12/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - acc: 0.8882 - loss: 0.3161 - val_acc: 0.7179 - val_loss: 0.8700 - learning_rate: 0.0025
# Epoch 13/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - acc: 0.8967 - loss: 0.2967 - val_acc: 0.8505 - val_loss: 0.4311 - learning_rate: 0.0012
# Epoch 14/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - acc: 0.8953 - loss: 0.2875 - val_acc: 0.6922 - val_loss: 1.3001 - learning_rate: 0.0012
# Epoch 15/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - acc: 0.8944 - loss: 0.2928 - val_acc: 0.8662 - val_loss: 0.3798 - learning_rate: 0.0012
# Epoch 16/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - acc: 0.8995 - loss: 0.2761 - val_acc: 0.7208 - val_loss: 0.8240 - learning_rate: 0.0012
# Epoch 17/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - acc: 0.9044 - loss: 0.2786 - val_acc: 0.8575 - val_loss: 0.4023 - learning_rate: 0.0012
# Epoch 18/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - acc: 0.9069 - loss: 0.2703 - val_acc: 0.7401 - val_loss: 0.7920 - learning_rate: 0.0012
# Epoch 19/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - acc: 0.9096 - loss: 0.2601 - val_acc: 0.8808 - val_loss: 0.3528 - learning_rate: 6.2500e-04
# Epoch 20/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - acc: 0.9071 - loss: 0.2695 - val_acc: 0.5292 - val_loss: 1.7966 - learning_rate: 6.2500e-04
# Epoch 21/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - acc: 0.9050 - loss: 0.2644 - val_acc: 0.8405 - val_loss: 0.4661 - learning_rate: 6.2500e-04
# Epoch 22/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - acc: 0.9075 - loss: 0.2657 - val_acc: 0.5678 - val_loss: 1.6976 - learning_rate: 6.2500e-04
# Epoch 23/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - acc: 0.9101 - loss: 0.2556 - val_acc: 0.8586 - val_loss: 0.3637 - learning_rate: 3.1250e-04
# Epoch 24/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - acc: 0.9069 - loss: 0.2583 - val_acc: 0.9258 - val_loss: 0.2366 - learning_rate: 3.1250e-04
# Epoch 25/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - acc: 0.9153 - loss: 0.2511 - val_acc: 0.9106 - val_loss: 0.2678 - learning_rate: 3.1250e-04
# Epoch 26/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - acc: 0.9077 - loss: 0.2550 - val_acc: 0.8820 - val_loss: 0.3419 - learning_rate: 3.1250e-04
# Epoch 27/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - acc: 0.9074 - loss: 0.2648 - val_acc: 0.9083 - val_loss: 0.2704 - learning_rate: 3.1250e-04
# Epoch 28/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - acc: 0.9085 - loss: 0.2534 - val_acc: 0.8762 - val_loss: 0.3485 - learning_rate: 1.5625e-04
# Epoch 29/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - acc: 0.9107 - loss: 0.2497 - val_acc: 0.8960 - val_loss: 0.2860 - learning_rate: 1.5625e-04
# Epoch 30/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - acc: 0.9139 - loss: 0.2494 - val_acc: 0.8884 - val_loss: 0.3187 - learning_rate: 1.5625e-04
# Epoch 31/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - acc: 0.9160 - loss: 0.2388 - val_acc: 0.9159 - val_loss: 0.2471 - learning_rate: 7.8125e-05
# Epoch 32/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - acc: 0.9116 - loss: 0.2552 - val_acc: 0.8908 - val_loss: 0.2930 - learning_rate: 7.8125e-05
# Epoch 33/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - acc: 0.9148 - loss: 0.2383 - val_acc: 0.8902 - val_loss: 0.2964 - learning_rate: 7.8125e-05
# Epoch 34/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - acc: 0.9123 - loss: 0.2454 - val_acc: 0.8995 - val_loss: 0.2859 - learning_rate: 3.9062e-05
# Epoch 35/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - acc: 0.9122 - loss: 0.2453 - val_acc: 0.8966 - val_loss: 0.2833 - learning_rate: 3.9062e-05
# Epoch 36/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - acc: 0.9115 - loss: 0.2446 - val_acc: 0.9019 - val_loss: 0.2737 - learning_rate: 3.9062e-05
# Epoch 37/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - acc: 0.9139 - loss: 0.2486 - val_acc: 0.9007 - val_loss: 0.2773 - learning_rate: 1.9531e-05
# Epoch 38/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - acc: 0.9157 - loss: 0.2398 - val_acc: 0.8954 - val_loss: 0.2928 - learning_rate: 1.9531e-05
# Epoch 39/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - acc: 0.9138 - loss: 0.2466 - val_acc: 0.8978 - val_loss: 0.2804 - learning_rate: 1.9531e-05
# Epoch 40/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - acc: 0.9176 - loss: 0.2392 - val_acc: 0.9007 - val_loss: 0.2795 - learning_rate: 9.7656e-06
# Epoch 41/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - acc: 0.9108 - loss: 0.2513 - val_acc: 0.8960 - val_loss: 0.2866 - learning_rate: 9.7656e-06
# Epoch 42/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - acc: 0.9104 - loss: 0.2619 - val_acc: 0.8954 - val_loss: 0.2865 - learning_rate: 9.7656e-06
# Epoch 43/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - acc: 0.9132 - loss: 0.2458 - val_acc: 0.8943 - val_loss: 0.2884 - learning_rate: 4.8828e-06
# Epoch 44/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - acc: 0.9145 - loss: 0.2464 - val_acc: 0.8949 - val_loss: 0.2889 - learning_rate: 4.8828e-06
# Epoch 45/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - acc: 0.9164 - loss: 0.2361 - val_acc: 0.8943 - val_loss: 0.2907 - learning_rate: 4.8828e-06
# Epoch 46/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - acc: 0.9169 - loss: 0.2313 - val_acc: 0.8949 - val_loss: 0.2888 - learning_rate: 2.4414e-06
# Epoch 47/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - acc: 0.9177 - loss: 0.2397 - val_acc: 0.8949 - val_loss: 0.2871 - learning_rate: 2.4414e-06
# Epoch 48/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - acc: 0.9186 - loss: 0.2482 - val_acc: 0.8960 - val_loss: 0.2876 - learning_rate: 2.4414e-06
# Epoch 49/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - acc: 0.9130 - loss: 0.2479 - val_acc: 0.8954 - val_loss: 0.2870 - learning_rate: 1.2207e-06

# %%
acc = hist.history['acc']
validation_acc = hist.history['val_acc']

loss = hist.history['loss']
val_loss = hist.history['val_loss']

range_epochs = np.arange(49)

plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(range_epochs,acc, label='Acuracia Treinamento')
plt.plot(range_epochs,validation_acc, label='Acuracia Validação')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

plt.subplot(1,2,2)
plt.plot(range_epochs,loss, label='Função Custo Treinamento')
plt.plot(range_epochs,val_loss, label='Função Custo Validação')
plt.legend(loc='upper right')
plt.grid(True)
plt.show()

# %%
model.save('deep_CNN_tf.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import itertools
#Plot the confusion matrix. Set Normalize = True/False
def plot_confusion_matrix(cm, classes, normalize=True, title='Confusion matrix', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize=(10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm = np.around(cm, decimals=2)
        cm[np.isnan(cm)] = 0.0
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
from sklearn.metrics import confusion_matrix
import pandas as pd

pred = model.predict(TestX_n,batch_size=batch_size)

y_pred = np.empty((len(pred),1),dtype=int)
for i in range(len(pred)):
    y_pred[i,0] = np.argmax(pred[i])

score = model.evaluate(TestX_n,TestY,batch_size=batch_size)

print(f'Função-Custo: {score[0]}')
print(f'Acurácia: {score[1]}')

print('--'*50)

cm = confusion_matrix(TestY,y_pred)
plot_confusion_matrix(cm, ['0', '1', '2', '3', '4', '5', '6', '7'], normalize=False, title='Confusion Matrix')
# Out:
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - acc: 0.8943 - loss: 0.3070
# Função-Custo: 0.285027414560318
# Acurácia: 0.9108448028564453
# ----------------------------------------------------------------------------------------------------

# %%
def plot_image(i, predictions_array, true_label, img):
  true_label, img = true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(predicted_label,
                                100*np.max(predictions_array),
                                true_label),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  true_label = true_label[i]
  plt.grid(False)
  plt.xticks(range(8))
  plt.yticks([])
  thisplot = plt.bar(range(8), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label[0]].set_color('blue')



num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, pred[i], TestY, TestX)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, pred[i], TestY)
plt.tight_layout()
plt.show()

# %%
i = 1
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, pred[i], TestY, TestX)
plt.subplot(1,2,2)
plot_value_array(i, pred[i],  TestY)
plt.show()

# %%
i = 8
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, pred[i], TestY, TestX)
plt.subplot(1,2,2)
plot_value_array(i, pred[i],  TestY)
plt.show()

# %%
i = 17
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, pred[i], TestY, TestX)
plt.subplot(1,2,2)
plot_value_array(i, pred[i],  TestY)
plt.show()

# %%
i = 19
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, pred[i], TestY, TestX)
plt.subplot(1,2,2)
plot_value_array(i, pred[i],  TestY)
plt.show()

# %%
i = 23
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, pred[i], TestY, TestX)
plt.subplot(1,2,2)
plot_value_array(i, pred[i],  TestY)
plt.show()

# %%
# %pip install graphviz pydot
# Out:
# Requirement already satisfied: graphviz in c:\users\jitesh\appdata\local\programs\python\python312\lib\site-packages (0.20.3)
# Requirement already satisfied: pydot in c:\users\jitesh\appdata\local\programs\python\python312\lib\site-packages (2.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\jitesh\appdata\local\programs\python\python312\lib\site-packages (from pydot) (3.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Carregar o modelo treinado e com acuracia global de 91.1% para o conjunto de test
from tensorflow.keras.models import load_model

model_load = load_model('deep_CNN_tf.h5')

score = model_load.evaluate(TestX_n,TestY,batch_size=64)

print(f'Função-Custo: {score[0]}')
print(f'Acurácia: {score[1]}')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - acc: 0.8943 - loss: 0.3070
# Função-Custo: 0.285027414560318
# Acurácia: 0.9108448028564453

# %%
tf.keras.utils.plot_model( model_load ,to_file='deepCNN.png', show_shapes=True )
